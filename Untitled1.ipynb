# %%
import seaborn as sns
import discretisedfield as df
import discretisedfield.util as dfu
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
p1 = (0, 0, 0)
p2 = (1e-9, 1e-9, 0.1e-9)
cell = (0.1e-9, 0.1e-9, 0.1e-9)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)

# %%
mesh.region.mpl()

# %%
mesh.region.mpl(figsize=(10, 6), multiplier=1e-9,
                   color=dfu.color_palette('deep', 10, 'rgb')[1], linewidth=3,
                   linestyle='dashed')

# %%
mesh.region.k3d()
# Out:
# Output()

# %%
p1 = (-50e9, -50e9, 0)
p2 = (50e9, 50e9, 20e9)
region = df.Region(p1=p1, p2=p2)

region.k3d()
# Out:
# Output()

# %%
region.k3d(multiplier=1e9,
            color=dfu.color_palette('deep', 10, 'int')[3],
            wireframe=True)
# Out:
# Output()

# %%
mesh.k3d_points()
# Out:
# Output()

# %%
p1 = (0, 0, 0)
p2 = (1e6, 1e6, 1e3)
cell = (0.1e6, 0.1e6, 1e3)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.k3d()
# Out:
# Output()

# %%
mesh.k3d_points(point_size=0.05)
# Out:
# Output()

# %%
p1 = (0, 0, 0)
p2 = (1.5e-6, 1.2e-6, 1.2e-6)
cell = (0.1e-6, 0.1e-6, 0.1e-6)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.k3d()
# Out:
# Output()

# %%
mesh.k3d_points()
# Out:
# Output()

# %%
p1 = (0, 0, 0)
p2 = (0.5e-6, 0.2e-6, 0.2e-6)
cell = (0.1e-6, 0.1e-6, 0.1e-6)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.k3d()
# Out:
# Output()

# %%
mesh.k3d_points()
# Out:
# Output()

# %%
p1 = (0, 0, 0)
p2 = (1e-6, 1e-6, 1e-9)
cell = (0.1e-6, 0.1e-6, 1e-9)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.k3d()
# Out:
# Output()

# %%
mesh.k3d_points()
# Out:
# Output()

# %%
p1 = (0, 0, 0)
p2 = (1e-9, 2e-9, 3e-9)
cell = (1e-9, 1e-9, 1e-9)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.k3d()
# Out:
# Output()

# %%
mesh.k3d_points()
# Out:
# Output()

# %%
mesh.region.mpl()

# %%
mesh.region.k3d()
# Out:
# Output()

# %%
p1 = (0, 0, 0)
p2 = (100, 120, 10)
cell = (2, 2, 2)
subregions = {'r1': df.Region(p1=(0, 0, 0), p2=(100, 10, 10)),
              'r2': df.Region(p1=(0, 10, 0), p2=(100, 20, 10)),
              'r3': df.Region(p1=(0, 20, 0), p2=(100, 30, 10)),
              'r4': df.Region(p1=(0, 30, 0), p2=(100, 40, 10)),
              'r5': df.Region(p1=(0, 40, 0), p2=(100, 50, 10)),
              'r6': df.Region(p1=(0, 50, 0), p2=(100, 60, 10)),
              'r7': df.Region(p1=(0, 60, 0), p2=(100, 70, 10)),
              'r8': df.Region(p1=(0, 70, 0), p2=(100, 80, 10)),
              'r9': df.Region(p1=(0, 80, 0), p2=(100, 90, 10)),
              'r10': df.Region(p1=(0, 90, 0), p2=(100, 100, 10)),
              'r11': df.Region(p1=(0, 100, 0), p2=(100, 110, 10)),
              'r12': df.Region(p1=(0, 110, 0), p2=(100, 120, 10))}
mesh = df.Mesh(p1=p1, p2=p2, cell=cell, subregions=subregions)
mesh.mpl_subregions(figsize=(10, 10), linewidth=1)

# %%
mesh.k3d_subregions()
# Out:
# Output()

# %%
mesh.k3d_points()
# Out:
# Output()

# %%
mesh.subregions['r2'].mpl()
