# %%
import seaborn as sns
import discretisedfield as df
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=None)
ax = fig.add_subplot(111, projection='3d')

# %%
p1 = (0, 0, 0)
p2 = (1e-9, 1e-9, 0.1e-9)
cell = (0.1e-9, 0.1e-9, 0.1e-9)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)

# %%
mesh.mpl()

# %%
dict(m = 1e-3)
# Out:
# {'m': 0.001}

# %%
mesh.mpl()

# %%
p1 = (0, 0, 0)
p2 = (1e6, 1e6, 1e3)
cell = (0.1e6, 0.1e6, 1e3)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
p1 = (0, 0, 0)
p2 = (1.5e-6, 1.2e-6, 1.2e-6)
cell = (0.1e-6, 0.1e-6, 0.1e-6)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
p1 = (0, 0, 0)
p2 = (0.5e-6, 0.2e-6, 0.2e-6)
cell = (0.1e-6, 0.1e-6, 0.1e-6)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
p1 = (0, 0, 0)
p2 = (1e-6, 1e-6, 1e-9)
cell = (0.1e-6, 0.1e-6, 1e-9)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.mpl()

# %%
p1 = (0, 0, 0)
p2 = (1e-6, 1e-6, 1e-6)
cell = (1e-9, 1e-9, 1e-9)
mesh = df.Mesh(p1=p1, p2=p2, cell=cell)
mesh.mpl()

# %%
mesh.region.mpl()

# %%
plot = mesh.region.k3d(colormap=l)
# Out:
# Output()

# %%
import matplotlib

l = []
for c in sns.color_palette():
    red = int(255 * c[0])
    green = int(255 * c[1])
    blue = int(255 * c[2])
    colors = (red << 16) + (green << 8) + blue
    l.append(colors) #int(hex(colors), 16)

l
# Out:
# [5010096,
#  14517330,
#  5613672,
#  12865106,
#  8483507,
#  9664608,
#  14322627,
#  9211020,
#  13416820,
#  6600141]

# %%
0x4C72B0

# %%
0.1 << 16
