# %%
import discretisedfield as df
import matplotlib.pyplot as plt
# %matplotlib inline

mesh = df.Mesh(p1=(-1,-1,-1), p2=(2,1,1), cell=(0.2,0.2,0.2))

def val(pos):
    x, y, z = pos
    #if x == 0.5:
    #    return (100, 0, 0)
    return y, x, x*y
    #return x*y

field = df.Field(mesh, value=val, dim=3)

# %%
#PYTEST_VALIDATE_IGNORE_OUTPUT
fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(111)

field.plot_slice(z=0, ax=ax)

# %%
field.norm.plot_slice("z")

# %%
field.y.plot_slice("z")

# %%
field.norm.average
# Out:
# (1.1440781670714142,)
