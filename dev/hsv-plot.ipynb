# %%
import os
import discretisedfield as df

# %%
test_filename = os.path.join('..', 'discretisedfield', 'tests','test_sample/','skyrmion.omf')

# %%
f = df.Field.fromfile(test_filename)
f.mesh.n
# Out:
# (20, 20, 1)

# %%
f.plane('z').angle.mpl_scalar(cmap='viridis')

# %%
f.plane('z').angle.mpl_scalar(lightness_field=f.z)

# %%
f.plane('z').angle.mpl(scalar_lightness_field=-f.z, vector_field=f)

# %%
g = f.zero
def val(point):
    x, y, z = point
    if x >=0:
        return (0, 0, 0)
    else:
        return (1, 1, 1)
g.value = val

# %%
f.plane('z').angle.mpl_scalar(lightness_field=-f.z, filter_field=g.x)
# Out:
# /home/marijanbeg/miniconda3/envs/ubermag-dev/lib/python3.8/colorsys.py:109: RuntimeWarning: invalid value encountered in double_scalars
#   hue = hue % 1.0

# %%
p1 = 100
