# %%
import os

import discretisedfield as df

# %%
test_filename = os.path.join('..', 'discretisedfield', 'tests','test_sample/','skyrmion.omf')

# %%
f = df.Field.fromfile(test_filename)
f.mesh.n
# Out:
# (20, 20, 1)

# %%
f.plane('z').angle.mpl_scalar(cmap='viridis', filter_field=f.norm)

# %%
f.plane('z').angle.mpl_scalar(lightness_field=f.z, filter_field=f.norm)
