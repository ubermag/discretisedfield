# %% [markdown]
# # Region

# %%
import k3d
import discretisedfield as df
import matplotlib.pyplot as plt

p1 = (-10e-9, -5e-9, -2e-9)
p2 = (10e-9, 5e-9, -2e-9)

#region = df.Region(p1=p1, p2=p2)

# %%
p1 = (-10e-9, -5e-9, -2e-9)
p2 = (10e-9, 5e-9, 2e-9)

region = df.Region(p1=p1, p2=p2)

# %%
region.pmin
# Out:
# (-1e-08, -5e-09, -2e-09)

# %%
region.pmax
# Out:
# (1e-08, 5e-09, 2e-09)

# %%
region.edges
# Out:
# (2e-08, 1e-08, 4e-09)

# %%
region.centre
# Out:
# (0.0, 0.0, 0.0)

# %%
region.volume
# Out:
# 8.000000000000001e-25

# %%
region.random_point()
# Out:
# (6.4678781719693765e-09, 5.479942032693809e-10, -5.080028830467005e-10)

# %%
repr(region)
# Out:
# 'Region(p1=(-1e-08, -5e-09, -2e-09), p2=(1e-08, 5e-09, 2e-09))'

# %%
region == region
# Out:
# True

# %%
region != region
# Out:
# False

# %%
region == 5
# Out:
# False

# %%
region != 5
# Out:
# True

# %%
(0, 0, 0) in region
# Out:
# True

# %%
region.pmin in region
# Out:
# True

# %%
region.mpl()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
region.mpl(ax=ax)
ax.set_xlabel('A')
# Out:
# Text(0.5, 0, 'A')

# %%
region.mpl(figsize=(5, 5))

# %%
region.mpl(figsize=(5, 5), color='#00ff00')

# %%
region.mpl(figsize=(6, 5), color='#00ff00', multiplier=1e-6)

# %%
region.mpl(figsize=(6, 5), color='#00ff00', multiplier=1e-6, linewidth=5)

# %%
region.mpl(figsize=(6, 6), color='#00ff00', multiplier=1e-6, linewidth=5, linestyle='dashed', filename='region.pdf')

# %%
region.k3d()
# Out:
# Output()

# %%
region.k3d(color=756659)
# Out:
# Output()

# %%
region.k3d(color=756659, multiplier=1e-12)
# Out:
# Output()

# %% [markdown]
# screenshot vs snapshot, other commands

# %%
region.k3d(color=756659, multiplier=1e-12, wireframe=True)
# Out:
# Output()

# %%
plot = k3d.plot()
plot.display()
region.k3d(plot=plot)
# Out:
# Output()

# %%
plot.axes = ['A', 'B', 'C']
